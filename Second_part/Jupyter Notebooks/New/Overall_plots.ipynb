# %%
# %store -r merge_binned_precipitation_upwind split_binned_precipitation_upwind nonmerge_binned_precipitation_upwind nonsplit_binned_precipitation_upwind
# %store -r merge_average_cell_per_bin_upwind split_average_cell_per_bin_upwind nonmerge_average_cell_per_bin_upwind nonsplit_average_cell_per_bin_upwind

# %store -r merge_binned_precipitation_urban split_binned_precipitation_urban nonmerge_binned_precipitation_urban nonsplit_binned_precipitation_urban
# %store -r merge_average_cell_per_bin_urban split_average_cell_per_bin_urban nonmerge_average_cell_per_bin_urban nonsplit_average_cell_per_bin_urban

# %store -r merge_binned_precipitation_downwind split_binned_precipitation_downwind nonmerge_binned_precipitation_downwind nonsplit_binned_precipitation_downwind
# %store -r merge_average_cell_per_bin_downwind split_average_cell_per_bin_downwind nonmerge_average_cell_per_bin_downwind nonsplit_average_cell_per_bin_downwind

# %store -r upwind_bins_lifetime_c frac_merge_upwind frac_nomerge_upwind frac_split_upwind frac_nosplit_upwind
# %store -r urban_bins_lifetime_c frac_merge_urban frac_nomerge_urban frac_split_urban frac_nosplit_urban
# %store -r downwind_bins_lifetime_c frac_merge_downwind frac_nomerge_downwind frac_split_downwind frac_nosplit_downwind

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt

mpl.rcParams['font.size'] = 17
mpl.rcParams['font.family'] = 'Arial'
mpl.rcParams['figure.facecolor'] = 'white'
fig, axes = plt.subplots(1, 3, figsize=[20,5], dpi=100)
fig.subplots_adjust(wspace=0.5, hspace=0.8)
boxprops_ = dict(linestyle='-', linewidth=0, color='k', facecolor='dodgerblue', alpha=1)
medianprops_ = dict(linestyle='-', linewidth=3, color='mediumblue')
meanpointprops_ = dict(marker='o', markeredgecolor='b', markerfacecolor='b', markersize=5)
whiskerprops_ = dict(linewidth=1, linestyle='-', color='dodgerblue')
fig.suptitle('Merged Cells', fontsize=20, y=1.05)
bin_labels = [1, 2, 3, 4, 5, 6, 7]

# First subplot
ax1 = axes[0]
ax1.boxplot(merge_binned_precipitation_upwind, positions=bin_labels, patch_artist=True, widths=0.3, notch=False, manage_ticks=False,
                  boxprops=boxprops_, medianprops=medianprops_, whis=[10,90], whiskerprops=whiskerprops_, 
                  showfliers=False, showmeans=True, meanprops=meanpointprops_, meanline=False, showcaps=False)
ax1.set_ylabel('Total Precipitation (mm)', color='blue')
ax1.set_xlim(0.5, 6.5, 1.5)
ax1.tick_params(axis='y', labelcolor='blue')
box_handle_merge = mpl.lines.Line2D([], [], color='dodgerblue', marker='_', markersize=15, 
                             markeredgewidth=1.5, label='Merge', linestyle='None')
#ax1.legend(handles=[box_handle_merge], loc='upper right')
ax1.set_title('(a) Upwind region', loc='left')
ax1.set_xlabel('Cell Lifetime (hour)')

ax1b = ax1.twinx()
ax1b.plot(bin_labels, merge_average_cell_per_bin_upwind, color='tomato', marker='o', linestyle='-', label='Avg Precipitation')
ax1b.set_ylabel('Cell Max Area (km$^2$)', color='red')
ax1b.tick_params(axis='y', labelcolor='red')
#ax1b.legend(loc='upper left')

# Second subplot
ax2 = axes[1]
ax2.boxplot(merge_binned_precipitation_urban, positions=bin_labels, patch_artist=True, widths=0.3, notch=False, manage_ticks=False,
                  boxprops=boxprops_, medianprops=medianprops_, whis=[10,90], whiskerprops=whiskerprops_, 
                  showfliers=False, showmeans=True, meanprops=meanpointprops_, meanline=False, showcaps=False)
ax2.set_ylabel('Total Precipitation (mm)', color='blue')
ax2.set_xlim(0.5, 6.5, 1.5)
ax2.tick_params(axis='y', labelcolor='blue')
box_handle_split = mpl.lines.Line2D([], [], color='dodgerblue', marker='_', markersize=15, 
                             markeredgewidth=1.5, label='Split', linestyle='None')
#ax2.legend(handles=[box_handle_split], loc='upper right')
ax2.set_title('(b) Urban region', loc='left')
ax2.set_xlabel('Cell Lifetime (hour)')

ax2b = ax2.twinx()
ax2b.plot(bin_labels, merge_average_cell_per_bin_urban, color='tomato', marker='o', linestyle='-', label='Avg Precipitation')
ax2b.set_ylabel('Cell Max Area (km$^2$)', color='red')
ax2b.tick_params(axis='y', labelcolor='red')

# Third subplot
ax3 = axes[2]
ax3.boxplot(merge_binned_precipitation_downwind, positions=bin_labels, patch_artist=True, widths=0.3, notch=False, manage_ticks=False,
                  boxprops=boxprops_, medianprops=medianprops_, whis=[10,90], whiskerprops=whiskerprops_, 
                  showfliers=False, showmeans=True, meanprops=meanpointprops_, meanline=False, showcaps=False)
ax3.set_ylabel('Total Precipitation (mm)', color='blue')
ax3.set_xlim(0.5, 6.5, 1.5)
ax3.tick_params(axis='y', labelcolor='blue')
box_handle_split = mpl.lines.Line2D([], [], color='dodgerblue', marker='_', markersize=15, 
                             markeredgewidth=1.5, label='Non-merge', linestyle='None')
#ax3.legend(handles=[box_handle_split], loc='upper right')
ax3.set_title('(c) Downwind region', loc='left')
ax3.set_xlabel('Cell Lifetime (hour)')

ax3b = ax3.twinx()
ax3b.plot(bin_labels, merge_average_cell_per_bin_downwind, color='tomato', marker='o', linestyle='-', label='Avg Precipitation')
ax3b.set_ylabel('Cell Max Area (km$^2$)', color='red')
ax3b.tick_params(axis='y', labelcolor='red')


ax1.grid(ls='--')
ax2.grid(ls='--')
ax3.grid(ls='--')
# Out:
# C:\Users\omitu\AppData\Local\Temp\ipykernel_31904\284415356.py:22: MatplotlibDeprecationWarning: Passing the emit parameter of set_xlim() positionally is deprecated since Matplotlib 3.6; the parameter will become keyword-only two minor releases later.
#   ax1.set_xlim(0.5, 6.5, 1.5)
# C:\Users\omitu\AppData\Local\Temp\ipykernel_31904\284415356.py:42: MatplotlibDeprecationWarning: Passing the emit parameter of set_xlim() positionally is deprecated since Matplotlib 3.6; the parameter will become keyword-only two minor releases later.
#   ax2.set_xlim(0.5, 6.5, 1.5)
# C:\Users\omitu\AppData\Local\Temp\ipykernel_31904\284415356.py:61: MatplotlibDeprecationWarning: Passing the emit parameter of set_xlim() positionally is deprecated since Matplotlib 3.6; the parameter will become keyword-only two minor releases later.
#   ax3.set_xlim(0.5, 6.5, 1.5)

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt

mpl.rcParams['font.size'] = 17
mpl.rcParams['font.family'] = 'Arial'
mpl.rcParams['figure.facecolor'] = 'white'
fig, axes = plt.subplots(1, 3, figsize=[20,5], dpi=100)
fig.subplots_adjust(wspace=0.5, hspace=0.8)
boxprops_ = dict(linestyle='-', linewidth=0, color='k', facecolor='dodgerblue', alpha=1)
medianprops_ = dict(linestyle='-', linewidth=3, color='mediumblue')
meanpointprops_ = dict(marker='o', markeredgecolor='b', markerfacecolor='b', markersize=5)
whiskerprops_ = dict(linewidth=1, linestyle='-', color='dodgerblue')
fig.suptitle('Split Cells', fontsize=20, y=1.05)
bin_labels = [1, 2, 3, 4, 5, 6, 7]

# First subplot
ax1 = axes[0]
ax1.boxplot(split_binned_precipitation_upwind, positions=bin_labels, patch_artist=True, widths=0.3, notch=False, manage_ticks=False,
                  boxprops=boxprops_, medianprops=medianprops_, whis=[10,90], whiskerprops=whiskerprops_, 
                  showfliers=False, showmeans=True, meanprops=meanpointprops_, meanline=False, showcaps=False)
ax1.set_ylabel('Total Precipitation (mm)', color='blue')
ax1.set_xlim(0.5, 6.5, 1.5)
ax1.tick_params(axis='y', labelcolor='blue')
box_handle_split = mpl.lines.Line2D([], [], color='dodgerblue', marker='_', markersize=15, 
                             markeredgewidth=1.5, label='split', linestyle='None')
#ax1.legend(handles=[box_handle_split], loc='upper right')
ax1.set_title('(a) Upwind region', loc='left')
ax1.set_xlabel('Cell Lifetime (hour)')

ax1b = ax1.twinx()
ax1b.plot(bin_labels, split_average_cell_per_bin_upwind, color='tomato', marker='o', linestyle='-', label='Avg Precipitation')
ax1b.set_ylabel('Cell Max Area (km$^2$)', color='red')
ax1b.tick_params(axis='y', labelcolor='red')
#ax1b.legend(loc='upper left')

# Second subplot
ax2 = axes[1]
ax2.boxplot(split_binned_precipitation_urban, positions=bin_labels, patch_artist=True, widths=0.3, notch=False, manage_ticks=False,
                  boxprops=boxprops_, medianprops=medianprops_, whis=[10,90], whiskerprops=whiskerprops_, 
                  showfliers=False, showmeans=True, meanprops=meanpointprops_, meanline=False, showcaps=False)
ax2.set_ylabel('Total Precipitation (mm)', color='blue')
ax2.set_xlim(0.5, 6.5, 1.5)
ax2.tick_params(axis='y', labelcolor='blue')
box_handle_split = mpl.lines.Line2D([], [], color='dodgerblue', marker='_', markersize=15, 
                             markeredgewidth=1.5, label='Split', linestyle='None')
#ax2.legend(handles=[box_handle_split], loc='upper right')
ax2.set_title('(b) Urban region', loc='left')
ax2.set_xlabel('Cell Lifetime (hour)')

ax2b = ax2.twinx()
ax2b.plot(bin_labels, split_average_cell_per_bin_urban, color='tomato', marker='o', linestyle='-', label='Avg Precipitation')
ax2b.set_ylabel('Cell Max Area (km$^2$)', color='red')
ax2b.tick_params(axis='y', labelcolor='red')

# Third subplot
ax3 = axes[2]
ax3.boxplot(split_binned_precipitation_downwind, positions=bin_labels, patch_artist=True, widths=0.3, notch=False, manage_ticks=False,
                  boxprops=boxprops_, medianprops=medianprops_, whis=[10,90], whiskerprops=whiskerprops_, 
                  showfliers=False, showmeans=True, meanprops=meanpointprops_, meanline=False, showcaps=False)
ax3.set_ylabel('Total Precipitation (mm)', color='blue')
ax3.set_xlim(0.5, 6.5, 1.5)
ax3.tick_params(axis='y', labelcolor='blue')
box_handle_split = mpl.lines.Line2D([], [], color='dodgerblue', marker='_', markersize=15, 
                             markeredgewidth=1.5, label='Non-split', linestyle='None')
#ax3.legend(handles=[box_handle_split], loc='upper right')
ax3.set_title('(c) Downwind region', loc='left')
ax3.set_xlabel('Cell Lifetime (hour)')

ax3b = ax3.twinx()
ax3b.plot(bin_labels, split_average_cell_per_bin_downwind, color='tomato', marker='o', linestyle='-', label='Avg Precipitation')
ax3b.set_ylabel('Cell Max Area (km$^2$)', color='red')
ax3b.tick_params(axis='y', labelcolor='red')


ax1.grid(ls='--')
ax2.grid(ls='--')
ax3.grid(ls='--')
# Out:
# C:\Users\omitu\AppData\Local\Temp\ipykernel_31904\536535830.py:22: MatplotlibDeprecationWarning: Passing the emit parameter of set_xlim() positionally is deprecated since Matplotlib 3.6; the parameter will become keyword-only two minor releases later.
#   ax1.set_xlim(0.5, 6.5, 1.5)
# C:\Users\omitu\AppData\Local\Temp\ipykernel_31904\536535830.py:42: MatplotlibDeprecationWarning: Passing the emit parameter of set_xlim() positionally is deprecated since Matplotlib 3.6; the parameter will become keyword-only two minor releases later.
#   ax2.set_xlim(0.5, 6.5, 1.5)
# C:\Users\omitu\AppData\Local\Temp\ipykernel_31904\536535830.py:61: MatplotlibDeprecationWarning: Passing the emit parameter of set_xlim() positionally is deprecated since Matplotlib 3.6; the parameter will become keyword-only two minor releases later.
#   ax3.set_xlim(0.5, 6.5, 1.5)

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt

mpl.rcParams['font.size'] = 17
mpl.rcParams['font.family'] = 'Arial'
mpl.rcParams['figure.facecolor'] = 'white'
fig, axes = plt.subplots(1, 3, figsize=[20,5], dpi=100)
fig.subplots_adjust(wspace=0.5, hspace=0.8)
boxprops_ = dict(linestyle='-', linewidth=0, color='k', facecolor='dodgerblue', alpha=1)
medianprops_ = dict(linestyle='-', linewidth=3, color='mediumblue')
meanpointprops_ = dict(marker='o', markeredgecolor='b', markerfacecolor='b', markersize=5)
whiskerprops_ = dict(linewidth=1, linestyle='-', color='dodgerblue')
fig.suptitle('Nonmerged Cells', fontsize=20, y=1.05)
bin_labels = [1, 2, 3, 4, 5, 6, 7]

# First subplot
ax1 = axes[0]
ax1.boxplot(nonmerge_binned_precipitation_upwind, positions=bin_labels, patch_artist=True, widths=0.3, notch=False, manage_ticks=False,
                  boxprops=boxprops_, medianprops=medianprops_, whis=[10,90], whiskerprops=whiskerprops_, 
                  showfliers=False, showmeans=True, meanprops=meanpointprops_, meanline=False, showcaps=False)
ax1.set_ylabel('Total Precipitation (mm)', color='blue')
ax1.set_xlim(0.5, 6.5, 1.5)
ax1.tick_params(axis='y', labelcolor='blue')
box_handle_nonmerge = mpl.lines.Line2D([], [], color='dodgerblue', marker='_', markersize=15, 
                             markeredgewidth=1.5, label='nonmerge', linestyle='None')
#ax1.legend(handles=[box_handle_nonmerge], loc='upper right')
ax1.set_title('(a) Upwind region', loc='left')
ax1.set_xlabel('Cell Lifetime (hour)')

ax1b = ax1.twinx()
ax1b.plot(bin_labels, nonmerge_average_cell_per_bin_upwind, color='tomato', marker='o', linestyle='-', label='Avg Precipitation')
ax1b.set_ylabel('Cell Max Area (km$^2$)', color='red')
ax1b.tick_params(axis='y', labelcolor='red')
#ax1b.legend(loc='upper left')

# Second subplot
ax2 = axes[1]
ax2.boxplot(nonmerge_binned_precipitation_urban, positions=bin_labels, patch_artist=True, widths=0.3, notch=False, manage_ticks=False,
                  boxprops=boxprops_, medianprops=medianprops_, whis=[10,90], whiskerprops=whiskerprops_, 
                  showfliers=False, showmeans=True, meanprops=meanpointprops_, meanline=False, showcaps=False)
ax2.set_ylabel('Total Precipitation (mm)', color='blue')
ax2.set_xlim(0.5, 6.5, 1.5)
ax2.tick_params(axis='y', labelcolor='blue')
box_handle_nonmerge = mpl.lines.Line2D([], [], color='dodgerblue', marker='_', markersize=15, 
                             markeredgewidth=1.5, label='nonmerge', linestyle='None')
#ax2.legend(handles=[box_handle_nonmerge], loc='upper right')
ax2.set_title('(b) Urban region', loc='left')
ax2.set_xlabel('Cell Lifetime (hour)')

ax2b = ax2.twinx()
ax2b.plot(bin_labels, nonmerge_average_cell_per_bin_urban, color='tomato', marker='o', linestyle='-', label='Avg Precipitation')
ax2b.set_ylabel('Cell Max Area (km$^2$)', color='red')
ax2b.tick_params(axis='y', labelcolor='red')

# Third subplot
ax3 = axes[2]
ax3.boxplot(nonmerge_binned_precipitation_downwind, positions=bin_labels, patch_artist=True, widths=0.3, notch=False, manage_ticks=False,
                  boxprops=boxprops_, medianprops=medianprops_, whis=[10,90], whiskerprops=whiskerprops_, 
                  showfliers=False, showmeans=True, meanprops=meanpointprops_, meanline=False, showcaps=False)
ax3.set_ylabel('Total Precipitation (mm)', color='blue')
ax3.set_xlim(0.5, 6.5, 1.5)
ax3.tick_params(axis='y', labelcolor='blue')
box_handle_nonmerge = mpl.lines.Line2D([], [], color='dodgerblue', marker='_', markersize=15, 
                             markeredgewidth=1.5, label='Non-nonmerge', linestyle='None')
#ax3.legend(handles=[box_handle_nonmerge], loc='upper right')
ax3.set_title('(c) Downwind region', loc='left')
ax3.set_xlabel('Cell Lifetime (hour)')

ax3b = ax3.twinx()
ax3b.plot(bin_labels, nonmerge_average_cell_per_bin_downwind, color='tomato', marker='o', linestyle='-', label='Avg Precipitation')
ax3b.set_ylabel('Cell Max Area (km$^2$)', color='red')
ax3b.tick_params(axis='y', labelcolor='red')


ax1.grid(ls='--')
ax2.grid(ls='--')
ax3.grid(ls='--')
# Out:
# C:\Users\omitu\AppData\Local\Temp\ipykernel_31904\4132227175.py:22: MatplotlibDeprecationWarning: Passing the emit parameter of set_xlim() positionally is deprecated since Matplotlib 3.6; the parameter will become keyword-only two minor releases later.
#   ax1.set_xlim(0.5, 6.5, 1.5)
# C:\Users\omitu\AppData\Local\Temp\ipykernel_31904\4132227175.py:42: MatplotlibDeprecationWarning: Passing the emit parameter of set_xlim() positionally is deprecated since Matplotlib 3.6; the parameter will become keyword-only two minor releases later.
#   ax2.set_xlim(0.5, 6.5, 1.5)
# C:\Users\omitu\AppData\Local\Temp\ipykernel_31904\4132227175.py:61: MatplotlibDeprecationWarning: Passing the emit parameter of set_xlim() positionally is deprecated since Matplotlib 3.6; the parameter will become keyword-only two minor releases later.
#   ax3.set_xlim(0.5, 6.5, 1.5)

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt

mpl.rcParams['font.size'] = 17
mpl.rcParams['font.family'] = 'Arial'
mpl.rcParams['figure.facecolor'] = 'white'
fig, axes = plt.subplots(1, 3, figsize=[20,5], dpi=100)
fig.subplots_adjust(wspace=0.5, hspace=0.8)
boxprops_ = dict(linestyle='-', linewidth=0, color='k', facecolor='dodgerblue', alpha=1)
medianprops_ = dict(linestyle='-', linewidth=3, color='mediumblue')
meanpointprops_ = dict(marker='o', markeredgecolor='b', markerfacecolor='b', markersize=5)
whiskerprops_ = dict(linewidth=1, linestyle='-', color='dodgerblue')
fig.suptitle('Nonsplit Cells', fontsize=20, y=1.05)
bin_labels = [1, 2, 3, 4, 5, 6, 7]

# First subplot
ax1 = axes[0]
ax1.boxplot(nonsplit_binned_precipitation_upwind, positions=bin_labels, patch_artist=True, widths=0.3, notch=False, manage_ticks=False,
                  boxprops=boxprops_, medianprops=medianprops_, whis=[10,90], whiskerprops=whiskerprops_, 
                  showfliers=False, showmeans=True, meanprops=meanpointprops_, meanline=False, showcaps=False)
ax1.set_ylabel('Total Precipitation (mm)', color='blue')
ax1.set_xlim(0.5, 6.5, 1.5)
ax1.tick_params(axis='y', labelcolor='blue')
box_handle_nonsplit = mpl.lines.Line2D([], [], color='dodgerblue', marker='_', markersize=15, 
                             markeredgewidth=1.5, label='nonsplit', linestyle='None')
#ax1.legend(handles=[box_handle_nonsplit], loc='upper right')
ax1.set_title('(a) Upwind region', loc='left')
ax1.set_xlabel('Cell Lifetime (hour)')

ax1b = ax1.twinx()
ax1b.plot(bin_labels, nonsplit_average_cell_per_bin_upwind, color='tomato', marker='o', linestyle='-', label='Avg Precipitation')
ax1b.set_ylabel('Cell Max Area (km$^2$)', color='red')
ax1b.tick_params(axis='y', labelcolor='red')
#ax1b.legend(loc='upper left')

# Second subplot
ax2 = axes[1]
ax2.boxplot(nonsplit_binned_precipitation_urban, positions=bin_labels, patch_artist=True, widths=0.3, notch=False, manage_ticks=False,
                  boxprops=boxprops_, medianprops=medianprops_, whis=[10,90], whiskerprops=whiskerprops_, 
                  showfliers=False, showmeans=True, meanprops=meanpointprops_, meanline=False, showcaps=False)
ax2.set_ylabel('Total Precipitation (mm)', color='blue')
ax2.set_xlim(0.5, 6.5, 1.5)
ax2.tick_params(axis='y', labelcolor='blue')
box_handle_nonsplit = mpl.lines.Line2D([], [], color='dodgerblue', marker='_', markersize=15, 
                             markeredgewidth=1.5, label='nonsplit', linestyle='None')
#ax2.legend(handles=[box_handle_nonsplit], loc='upper right')
ax2.set_title('(b) Urban region', loc='left')
ax2.set_xlabel('Cell Lifetime (hour)')

ax2b = ax2.twinx()
ax2b.plot(bin_labels, nonsplit_average_cell_per_bin_urban, color='tomato', marker='o', linestyle='-', label='Avg Precipitation')
ax2b.set_ylabel('Cell Max Area (km$^2$)', color='red')
ax2b.tick_params(axis='y', labelcolor='red')

# Third subplot
ax3 = axes[2]
ax3.boxplot(nonsplit_binned_precipitation_downwind, positions=bin_labels, patch_artist=True, widths=0.3, notch=False, manage_ticks=False,
                  boxprops=boxprops_, medianprops=medianprops_, whis=[10,90], whiskerprops=whiskerprops_, 
                  showfliers=False, showmeans=True, meanprops=meanpointprops_, meanline=False, showcaps=False)
ax3.set_ylabel('Total Precipitation (mm)', color='blue')
ax3.set_xlim(0.5, 6.5, 1.5)
ax3.tick_params(axis='y', labelcolor='blue')
box_handle_nonsplit = mpl.lines.Line2D([], [], color='dodgerblue', marker='_', markersize=15, 
                             markeredgewidth=1.5, label='Non-nonsplit', linestyle='None')
#ax3.legend(handles=[box_handle_nonsplit], loc='upper right')
ax3.set_title('(c) Downwind region', loc='left')
ax3.set_xlabel('Cell Lifetime (hour)')

ax3b = ax3.twinx()
ax3b.plot(bin_labels, nonsplit_average_cell_per_bin_downwind, color='tomato', marker='o', linestyle='-', label='Avg Precipitation')
ax3b.set_ylabel('Cell Max Area (km$^2$)', color='red')
ax3b.tick_params(axis='y', labelcolor='red')


ax1.grid(ls='--')
ax2.grid(ls='--')
ax3.grid(ls='--')
# Out:
# C:\Users\omitu\AppData\Local\Temp\ipykernel_31904\4063807235.py:22: MatplotlibDeprecationWarning: Passing the emit parameter of set_xlim() positionally is deprecated since Matplotlib 3.6; the parameter will become keyword-only two minor releases later.
#   ax1.set_xlim(0.5, 6.5, 1.5)
# C:\Users\omitu\AppData\Local\Temp\ipykernel_31904\4063807235.py:42: MatplotlibDeprecationWarning: Passing the emit parameter of set_xlim() positionally is deprecated since Matplotlib 3.6; the parameter will become keyword-only two minor releases later.
#   ax2.set_xlim(0.5, 6.5, 1.5)
# C:\Users\omitu\AppData\Local\Temp\ipykernel_31904\4063807235.py:61: MatplotlibDeprecationWarning: Passing the emit parameter of set_xlim() positionally is deprecated since Matplotlib 3.6; the parameter will become keyword-only two minor releases later.
#   ax3.set_xlim(0.5, 6.5, 1.5)

# %%
import matplotlib.pyplot as plt

# Set the font properties
plt.rcParams['font.size'] = 15
plt.rcParams['font.family'] = 'Arial'

# Create a 2 by 2 grid of subplots
fig, axs = plt.subplots(2, 2, figsize=(16, 10), dpi=100)

# Plot on the first subplot (top-left)
ax1 = axs[0,0]
ax1.plot(upwind_bins_lifetime_c, frac_merge_upwind, color='red', label='Upwind', marker='o')
ax1.plot(upwind_bins_lifetime_c, frac_merge_urban, color='blue', alpha=0.8, label='Urban', marker='o')
ax1.plot(upwind_bins_lifetime_c, frac_merge_downwind, color='green', alpha=0.8, label='Downwind', marker='o')
ax1.set_xlabel('Cell Lifetime (hour)')
ax1.set_ylabel('Percentage of Cells (%)')
ax1.set_title('(a) Merged Cells', loc='left')
ax1.grid(ls='--')
ax1.legend()

# [The same structure can be used to plot other data on the remaining three subplots:
# axs[0, 1], axs[1, 0], and axs[1, 1]]

# For example, plotting on the second subplot (top-right)
ax2 = axs[0,1]
ax2.plot(upwind_bins_lifetime_c, frac_nomerge_upwind, color='red', label='Upwind', marker='o')
ax2.plot(upwind_bins_lifetime_c, frac_nomerge_urban, color='blue', alpha=0.8, label='Urban', marker='o')
ax2.plot(upwind_bins_lifetime_c, frac_nomerge_downwind, color='green', alpha=0.8, label='Downwind', marker='o')
ax2.set_xlabel('Cell Lifetime (hour)')
ax2.set_ylabel('Percentage of Cells (%)')
ax2.set_title('(b) No-merge Cells', loc='left')
ax2.grid(ls='--')
ax2.legend()

ax3 = axs[1,0]
ax3.plot(upwind_bins_lifetime_c, frac_split_upwind, color='red', label='Upwind', marker='o')
ax3.plot(upwind_bins_lifetime_c, frac_split_urban, color='blue', alpha=0.8, label='Urban', marker='o')
ax3.plot(upwind_bins_lifetime_c, frac_split_downwind, color='green', alpha=0.8, label='Downwind', marker='o')
ax3.set_xlabel('Cell Lifetime (hour)')
ax3.set_ylabel('Percentage of Cells (%)')
ax3.set_title('(c) Split Cells', loc='left')
ax3.grid(ls='--')
ax3.legend()

ax4 = axs[1,1]
ax4.plot(upwind_bins_lifetime_c, frac_nosplit_upwind, color='red', label='Upwind', marker='o')
ax4.plot(upwind_bins_lifetime_c, frac_nosplit_urban, color='blue', alpha=0.8, label='Urban', marker='o')
ax4.plot(upwind_bins_lifetime_c, frac_nosplit_downwind, color='green', alpha=0.8, label='Downwind', marker='o')
ax4.set_xlabel('Cell Lifetime (hour)')
ax4.set_ylabel('Percentage of Cells (%)')
ax4.set_title('(d) No-split Cells', loc='left')
ax4.grid(ls='--')
ax4.legend()

# Add a suptitle above all subplots
fig.suptitle('Percentage of Cells in Each Zone Based on Lifetime', fontsize=20, y=0.95)

# Adjust layout for better fit
plt.tight_layout(rect=[0, 0.03, 1, 0.95])

# Show the plot
plt.show()

# Optional: Save the figure to a file
# fig.savefig(f'{figdir}celltrack_lifetime_pdf.png', bbox_inches='tight', dpi=300, facecolor='w')

# %%
upwind_bins_lifetime_c
# Out:
# array([1, 2, 3, 4, 5, 6, 7])
